# %% [markdown]
# # 00 — Environment and tests
# Confirm the kernel, package import, and complete unit-test suite before running experiments.

# %%
import platform, sys, warnings
from pathlib import Path
warnings.filterwarnings('ignore', category=RuntimeWarning)
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
print(sys.executable)
print(platform.python_version())
print(ROOT)
# Out:
# /Users/jonathanma/Desktop/Projects/innovative-droBVAR/.venv/bin/python
# 3.10.4
# /Users/jonathanma/Desktop/Projects/innovative-droBVAR

# %%
import innovcal
print('innovcal', innovcal.__version__)
# Out:
# innovcal 0.1.0

# %%
import subprocess
completed = subprocess.run([sys.executable, '-m', 'pytest', '-q'], cwd=ROOT, text=True, capture_output=True)
print(completed.stdout)
assert completed.returncode == 0, completed.stderr
# Out:
# ..........                                                               [100%]
# 10 passed in 1.88s
