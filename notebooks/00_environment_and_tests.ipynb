# %% [markdown]
# # 00 — Environment and tests
#
# Run this notebook first. It verifies the package layout and executes the fast source-level test suite.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))

import innovcal
print('project:', ROOT)
print('innovcal:', innovcal.__version__)
# Out:
# project: /Users/jonathanma/Desktop/Projects/innovative-droBVAR
# innovcal: 0.1.0

# %%
import os
import subprocess

completed = subprocess.run(
    [sys.executable, '-m', 'unittest', 'discover', '-s', 'tests', '-v'],
    cwd=ROOT,
    check=False,
    env={**os.environ, 'PYTHONPATH': str(ROOT / 'src')},
)
assert completed.returncode == 0, 'Tests failed; stop before running experiments.'
# Out:
# test_tiny_fit_and_forecast (test_di_var.DIVARSmokeTests) ... ok
# test_quantiles_have_horizon_by_series_shape (test_di_var.ForecastResultTests) ... ok
# test_output_shape_and_determinism (test_di_var.RollingResidualTests) ... ok
# test_rejects_invalid_window (test_di_var.RollingResidualTests) ... ok
# test_chronological_split (test_financial_data.FinancialDataTests) ... ok
# test_demo_prices_are_positive_and_reproducible (test_financial_data.FinancialDataTests) ... ok
# test_log_returns (test_financial_data.FinancialDataTests) ... ok
# test_classical_workflow (test_financial_experiment.FinancialExperimentTests) ... ok
#
# ----------------------------------------------------------------------
# Ran 8 tests in 0.567s
#
# OK

# %% [markdown]
# Expected result: all fast tests pass. The remaining notebooks write reproducible intermediate artifacts under `results/notebook_cache/`.
